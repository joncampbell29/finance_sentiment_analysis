# %%
print("hello")
# Out:
# hello

# %%
# Adding test change

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/personal/finance_sentiment_analysis
# Out:
# /content/drive/MyDrive/personal/finance_sentiment_analysis

# %%
with open('/content/drive/MyDrive/.env', 'w') as f:
    f.write("GITHUB_TOKEN=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")

# %%
from dotenv import load_dotenv
import os
load_dotenv('/content/drive/MyDrive/.env')
# Out:
# True

# %%
# !pip install python-dotenv
# from dotenv import load_dotenv
# import os

# Load the .env file
# load_dotenv('/content/drive/MyDrive/.env')

# Use the token for Git operations
token = os.getenv('GITHUB_TOKEN')
os.environ['GIT_ASKPASS'] = 'echo'
os.environ['GIT_USERNAME'] = 'joncampbell29'
os.environ['GIT_PASSWORD'] = token

# %%
# Make your changes here
# !git config --global user.email "campbelljonjr@comcast.net"
# !git config --global user.name "Jon Campbell"
# !git add .
# !git commit -m "test commit from google colab"
# !git push https://$GIT_USERNAME:$GIT_PASSWORD@github.com/yourusername/your-repo.git
