# %%
import requests
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
key = os.getenv("NEWS_API_KEY")

# %%
url = "https://newsapi.org/v2/everything"
payload = {
    'q': "+Apple",
    'from': '2024-07-01',
    'sortBy': 'popularity',
    'apikey': key
}

# %%
resp = requests.get(url, params = payload)

# %%
resp.status_code
# Out:
# 200

# %%
resp.json()['totalResults']
# Out:
# 6265

# %%
articles = resp.json()['articles']
len(articles)
# Out:
# 100

# %%
articles = [art for art in articles if art['source']['name'] != '[Removed]']

# %%
filt_articles = [art for art in articles if art['source']['name'] in ('Business Insider', 'The Verge', 'CNET')]

# %%
articles
# Out:
# [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Mariella Moon',
#   'title': 'Apple says Vision Pro will allow alternate payment methods in the EU',
#   'description': 'The European Commission designated Apple as a gatekeeper under the Digital Markets Act for its iOS and iPadOS platforms, as well as its App Store and its Safari browser. VisionOS is nowhere in that list, but Apple is getting ahead of the commission this time …',
#   'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_51fcf7ff-ebb2-4832-b333-6dab0a66f747',
#   'urlToImage': None,
#   'publishedAt': '2024-07-02T14:30:38Z',
#   'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Danny Gallagher',
#   'title': 'A new Resident Evil game is in the works from the director of Resident Evil 7',
#   'description': 'It’s been a hot minute since we’ve had a brand new Resident Evil game. Then again, it’s hard to blame Capcom for that — Resident Evil: Village created such a high bar for future sequels to limbo under or jump over, depending on which hypothetical bar-based sp…',
#   'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_5b055c4f-4ed8-41dd-a558-4e37c308953c',
#   'urlToImage': None,
#   'publishedAt': '2024-07-02T23:55:43Z',
#   'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Mariella Moon',
#   'title': 'NFC Forum wants to bundle age verification and payment receipts in tap-to-pay',
#   'description': 'The NFC Forum, the non-profit org made up of big tech companies promoting the NFC standard, envisions a future wherein one tap is all you need for multiple actions at once. With a single tap, for instance, you could pay for your purchase, get points on your r…',
#   'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_149de27f-ad45-48d6-bbe8-a3ad172ed8f9',
#   'urlToImage': None,
#   'publishedAt': '2024-07-02T04:30:46Z',
#   'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Steve Dent',
#   'title': "The iPad and Blackmagic's Micro Color Panel make strange bedfellows",
#   'description': 'With the current rebellion against Adobe’s subscription model, folks are taking a hard look at Blackmagic Design’s DaVinci Resolve Studio. And many like what they see. It’s arguably more powerful than Adobe’s Premiere Pro, offering better color correction too…',
#   'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_897028a3-2d97-4fe4-8a27-5e7c1d196be3',
#   'urlToImage': None,
#   'publishedAt': '2024-07-03T18:38:35Z',
#   'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'Apple’s Phil Schiller is reportedly joining OpenAI’s board',
#   'description': 'Apple exec Phil Schiller is said to be joining OpenAI’s board in a non-voting observer position, according to a report from Bloomberg. ChatGPT is being integrated into iOS and macOS later this year.',
#   'url': 'https://www.theverge.com/2024/7/2/24191105/apple-phil-schiller-join-openai-board',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/EEBmDh6emjqUa-wKnQI-JyZ-7lQ=/0x0:2040x1360/1200x628/filters:focal(1020x680:1021x681)/cdn.vox-cdn.com/uploads/chorus_asset/file/23598986/VRG_Illo_5258_K_Radtke_WWDC.jpg',
#   'publishedAt': '2024-07-02T22:20:20Z',
#   'content': 'Illustration by Kristen Radtke / The Verge\r\n\n \n\n Apple has chosen App Store chief and former marketing head Phil Schiller to represent the company on OpenAI’s nonprofit board, according to a report f… [+1057 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jennifer Pattison Tuohy',
#   'title': 'SmartThings adds\xa0Matter\xa0support for appliances and robot vacuums',
#   'description': 'The move will bring Matter-compatible robot vacuums, fridges, washing machines, air purifiers, and more to Samsung’s smart home platform.',
#   'url': 'https://www.theverge.com/2024/7/1/24189785/samsung-smartthings-matter-1-2-support-robot-vacuums',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/SCQERxZ4PE0wo8n-zUcmB4H4UWg=/0x0:1080x1080/1200x628/filters:focal(540x540:541x541)/cdn.vox-cdn.com/uploads/chorus_asset/file/25513308/R2_Image_2.jpg',
#   'publishedAt': '2024-07-01T14:30:05Z',
#   'content': 'SmartThings adds\xa0Matter\xa0support for appliances and robot vacuums\r\nSmartThings adds\xa0Matter\xa0support for appliances and robot vacuums\r\n / Samsung is taking the lead in Matter adoption by adding full Mat… [+7231 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Antonio G. Di Benedetto',
#   'title': 'Netflix’s latest game is a mobile take on Minesweeper',
#   'description': 'The latest Netflix game to come to the streaming giant’s service is a classic that’s best known as being a time-waster on Windows.',
#   'url': 'https://www.theverge.com/2024/7/2/24190961/netflix-games-minesweeper-subscribers-launch-trailer',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/S0hvlUykChWMGG8GB0nVZy54Ucc=/0x0:2048x2732/1200x628/filters:focal(1024x1366:1025x1367)/cdn.vox-cdn.com/uploads/chorus_asset/file/25515570/minesweeper_netflix_screenshot.jpg',
#   'publishedAt': '2024-07-02T19:43:44Z',
#   'content': 'Netflixs latest game is a mobile take on Minesweeper\r\nNetflixs latest game is a mobile take on Minesweeper\r\n / Straight outta Windows 3.11 and into your Netflix subscription, with much better graphic… [+1692 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Quentyn Kennemer',
#   'title': 'Mark Zuckerberg experiments with six-window Quest VR multitasking',
#   'description': 'Meta’s version 67 of Horizon OS for Quest headsets supports more virtual windows that you can put in more places and new creator videos in the Horizon Feed.',
#   'url': 'https://www.theverge.com/2024/7/3/24191722/meta-quest-horizon-os-67-multitasking-update',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/aY8-8ZSzCvmFkz-0RCbdB0O6VT0=/0x149:1920x930/1200x628/filters:focal(960x540:961x541)/cdn.vox-cdn.com/uploads/chorus_asset/file/25517132/meta_quest_v67_windows.jpg',
#   'publishedAt': '2024-07-03T20:16:36Z',
#   'content': 'Mark Zuckerberg experiments with six-window Quest VR multitasking\r\nMark Zuckerberg experiments with six-window Quest VR multitasking\r\n / The new Horizon OS version 67 update for Metas Quest headsets … [+2094 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Wes Davis',
#   'title': 'Facebook and Instagram’s ‘pay or consent’ ad model violates the DMA, says the EU',
#   'description': 'Meta’s paid opt-out plan for Facebook and Instagram ads allegedly violates the EU by not giving users an option for a “similar experience” with less personalization.',
#   'url': 'https://www.theverge.com/2024/7/1/24189796/eu-meta-dma-violation-pay-consent-ads-model',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/E5LPkCRcJj-txc18rOrA4AFA5CI=/0x0:2040x1360/1200x628/filters:focal(1020x680:1021x681)/cdn.vox-cdn.com/uploads/chorus_asset/file/24814378/STK450_European_Union_02.jpg',
#   'publishedAt': '2024-07-01T12:57:16Z',
#   'content': 'Facebook and Instagrams pay or consent ad model violates the DMA, says the EU\r\nFacebook and Instagrams pay or consent ad model violates the DMA, says the EU\r\n / Meta joins Apple as the second big tec… [+2892 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Lucas Ropek',
#   'title': 'New Open Source Bugs Leave Thousands of iOS Apps Vulnerable to Hijacking',
#   'description': 'A series of newly discovered vulnerabilities in a widely used open source software utility could spell big trouble for large parts of the iOS and MacOS ecosystems. The bugs in question could impact thousands of widely used apps, including popular programs lik…',
#   'url': 'https://gizmodo.com/new-open-source-bugs-leave-thousands-of-ios-apps-vulner-1851573395',
#   'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/753e6e2c90a4c6e8d1537382fe6bcc87.jpg',
#   'publishedAt': '2024-07-02T20:40:00Z',
#   'content': 'A series of newly discovered vulnerabilities in a widely used open source software utility could spell big trouble for large parts of the iOS and MacOS ecosystems. The bugs in question could impact t… [+3902 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Lucas Ropek',
#   'title': 'People in San Francisco Are Mad That a New App Lets You Spy on Bars to See How Busy They Are',
#   'description': 'A weird new app lets San Francisco residents monitor local bars via live video feed to see what’s happening there and to check how busy the venues are. 2Nite, which launched earlier this year, uses a network of cameras at various Bay Area establishments to pr…',
#   'url': 'https://gizmodo.com/2nite-app-lets-you-spy-on-bars-to-see-how-busy-they-are-1851571595',
#   'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/da9be211f1680b84035f5ff0fd8a4524.jpg',
#   'publishedAt': '2024-07-02T12:35:00Z',
#   'content': 'A weird new app lets San Francisco residents monitor local bars via live video feed to see whats happening there and to check how busy the venues are. 2Nite, which launched earlier this year, uses a … [+1876 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'David Nield',
#   'title': 'How to Make Your Home Screen Prettier and Less Boring',
#   'description': "Don't settle for the same old wallpaper every single day.",
#   'url': 'https://gizmodo.com/how-to-make-your-home-screen-prettier-and-less-boring-1851574717',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2024/07/fcfedcd7dcd05f3183471828fa2504db.jpg',
#   'publishedAt': '2024-07-04T11:00:01Z',
#   'content': 'Theres no end of choice when picking a backdrop for your phones home screens, and if you cannot settle on a single image, why not make an auto-rotating selection? Its not difficult to do on either An… [+3766 chars]'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': 'Bad Sisters star Duff to return to London stage',
#   'description': 'Actress Anne-Marie Duff, who has also appeared in Sex Education, will perform at the Young Vic.',
#   'url': 'https://www.bbc.com/news/articles/c3g9km04nzdo',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/abe7/live/8e727280-3522-11ef-bdc5-41d7421c2adf.jpg',
#   'publishedAt': '2024-07-03T02:16:43Z',
#   'content': 'By\xa0Steven McIntosh,\xa0Entertainment reporter\r\nSex Education star Anne-Marie Duff is returning to the London stage for a new production of 1930s play The Little Foxes.\r\nThe actress won a Bafta TV Award … [+1846 chars]'},
#  {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#   'author': 'Scharon Harding',
#   'title': 'Apple Vision Pro, new cameras fail user-repairability analysis',
#   'description': 'Meta Quest 3, PS5 Slim also received failing grades despite new right-to-repair laws.',
#   'url': 'https://arstechnica.com/gadgets/2024/07/apple-vision-pro-new-cameras-fail-user-repairability-analysis/',
#   'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2024/02/IMG_6320-760x380.jpg',
#   'publishedAt': '2024-07-02T21:32:31Z',
#   'content': 'Enlarge/ Apple\'s Vision Pro scored 0 points in US PIRG\'s self-repairability analysis. \r\n3\r\nIn December, New York became the first state to enact a "Right to Repair" law for electronics. Since then, o… [+3217 chars]'},
#  {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#   'author': 'Scharon Harding',
#   'title': 'Bleeding subscribers, cable companies force their way into streaming',
#   'description': 'Companies like Charter brought about the streaming industry they now want to join.',
#   'url': 'https://arstechnica.com/gadgets/2024/07/bleeding-subscribers-cable-companies-force-their-way-into-streaming/',
#   'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2024/03/tv-remote-760x380.jpg',
#   'publishedAt': '2024-07-01T19:20:13Z',
#   'content': "40\r\nIt's clear that streaming services are the present and future of video distribution. But that doesn't mean that cable companies are ready to give up on your monthly dollars.\r\nA sign of this is Co… [+3892 chars]"},
#  {'source': {'id': None, 'name': 'Android Central'},
#   'author': 'Nicholas Sutrich',
#   'title': "This is the one Samsung device you probably shouldn't expect at Galaxy Unpacked",
#   'description': "Samsung and Google are making an Apple Vision Pro competitor but it's taking a bit longer than expected. Here's what's going on.",
#   'url': 'https://www.androidcentral.com/gaming/virtual-reality/dont-expect-samsung-xr-headset-galaxy-unpacked-2024',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/tSPmQJ5Y3RC35cJQJc2VJF-1200-80.jpg',
#   'publishedAt': '2024-07-04T16:00:33Z',
#   'content': "When Apple Vision Pro was announced last Summer, it purportedly sent Google and Samsung scrambling to come up with a competitor. Apple had been working on this tech for years yet, despite Google's ye… [+5812 chars]"},
#  {'source': {'id': None, 'name': 'Android Central'},
#   'author': 'techkritiko@gmail.com (Jay Bonggolto)',
#   'title': "The Google Pixel 9 might crush the Galaxy S24 Ultra's screen game",
#   'description': "The Pixel 9 series is supposedly getting Samsung's latest and greatest OLED tech.",
#   'url': 'https://www.androidcentral.com/phones/the-google-pixel-9-might-crush-the-galaxy-s24-ultras-screen-game',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/NeW7yGLqNLaYFmz8oh4bci-1200-80.jpg',
#   'publishedAt': '2024-07-01T10:56:33Z',
#   'content': "What you need to know\r\n<ul><li>The Google Pixel 9 might use Samsung’s top-notch M14 OLED display.</li><li>Samsung' advanced M14 screens supposedly offer better brightness, longevity, and power effici… [+2149 chars]"},
#  {'source': {'id': None, 'name': 'Android Central'},
#   'author': 'techkritiko@gmail.com (Jay Bonggolto)',
#   'title': 'Your Android phone can now double as a hotel room key thanks to Google Wallet',
#   'description': 'Google Wallet now stores your hotel room keys on your phone.',
#   'url': 'https://www.androidcentral.com/apps-software/your-android-phone-can-now-double-as-a-hotel-room-key-thanks-to-google-wallet',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/MVmCk9Ug8dRT4g9HQBSgYX-1200-80.jpg',
#   'publishedAt': '2024-07-01T09:43:10Z',
#   'content': 'What you need to know\r\n<ul><li>Google Wallet now lets you store digital hotel key cards on your Android phone, replacing physical keys and extra hotel apps.</li><li>You can add your digital key via t… [+2398 chars]'},
#  {'source': {'id': None, 'name': 'Android Central'},
#   'author': 'tips@androidcentral.com (Nickolas Diaz)',
#   'title': 'Go big or go home — the Galaxy Tab S10 series might ditch the basic model',
#   'description': 'A report claims that Samsung could skip a base Galaxy Tab S10 model later this year.',
#   'url': 'https://www.androidcentral.com/tablets/samsung-drops-basic-tab-s10-rumors',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/MecTZdNduJtgy5X9p8xeHh-1200-80.jpg',
#   'publishedAt': '2024-07-01T18:52:51Z',
#   'content': 'What you need to know\r\n<ul><li>A report claims that Samsung could drop a base Tab S10 model in favor of plugging display upgrades into its Plus and Ultra variants.</li><li>Supposedly, Samsung will sw… [+2550 chars]'},
#  {'source': {'id': None, 'name': 'Android Central'},
#   'author': 'harish.jonnalagadda@futurenet.com (Harish Jonnalagadda)',
#   'title': "Ultrahuman's Ring Air is terrific — here's what I want to see in the Galaxy Ring",
#   'description': "I used a smart ring for most of 2024, and I think it has the potential to redefine wearables. With Samsung set to launch the Galaxy Ring soon, here's what I want to see in the brand's smart ring.",
#   'url': 'https://www.androidcentral.com/wearables/ultrahumans-ring-air-is-terrific-heres-what-i-want-to-see-in-the-galaxy-ring',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/YfqvMSCCxKbLw7zSnUdfPb-1200-80.jpg',
#   'publishedAt': '2024-07-03T13:45:26Z',
#   'content': "I used smartwatches for close to a decade, starting out with Android Wear and switching over to the Apple Watch five years ago. I like the convenience it offers; it's great to mirror notifications to… [+4630 chars]"},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Tim Hardwick',
#   'title': 'Some Apple Intelligence Features Likely to Require Paid Subscription',
#   'description': 'Apple eventually plans to turn some of its artificial intelligence features into paid services, similar to iCloud+ subscriptions, according to Bloomberg reporter Mark Gurman.\n\n\n\n\n\nWriting in his latest Power On newsletter, Gurman said that while Apple Intelli…',
#   'url': 'https://www.macrumors.com/2024/07/01/apple-intelligence-features-likely-paid-sub/',
#   'urlToImage': 'https://images.macrumors.com/t/eNxYmCA1u77ZdJovI2KACUQ_lN0=/2500x/article-new/2024/06/Apple-Intelligence-General-Feature.jpg',
#   'publishedAt': '2024-07-01T10:51:36Z',
#   'content': 'Apple eventually plans to turn some of its artificial intelligence features into paid services, similar to iCloud+ subscriptions, according to Bloomberg reporter Mark Gurman.\r\nWriting in his latest P… [+1124 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'Apple Seeds Second Beta of macOS Sonoma 14.6 to Developers',
#   'description': 'Apple today seeded the second beta of an upcoming macOS Sonoma 14.6 update to developers, with the second software coming two weeks after Apple released the first beta.\n\n\n\n\n\nRegistered developers can opt-in to the beta through the Software Update section of t…',
#   'url': 'https://www.macrumors.com/2024/07/01/apple-seeds-macos-sonoma-14-6-beta-2/',
#   'urlToImage': 'https://images.macrumors.com/t/hlTPUK2T2TO3h1-KxJcbOulRzRY=/1600x/article-new/2023/06/sonoma-desktop-wwdc.jpg',
#   'publishedAt': '2024-07-01T17:13:44Z',
#   'content': 'Apple today seeded the second beta of an upcoming macOS Sonoma 14.6 update to developers, with the second software coming two weeks after Apple released the first beta.\r\nRegistered developers can opt… [+293 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Tim Hardwick',
#   'title': 'Apple Watch Ultra 3: Everything We Know So Far',
#   'description': 'The Apple Watch Ultra 3, likely to be released in September 2024 alongside the iPhone 16, is expected to offer fewer upgrades compared to its predecessor, the Apple Watch Ultra 2. Keep reading to learn what the rumored changes are.\n\n\n\n\n\nWhen Apple Watch Ultra…',
#   'url': 'https://www.macrumors.com/guide/apple-watch-ultra-3-everything-we-know/',
#   'urlToImage': 'https://images.macrumors.com/t/H8hF7frgjmLf5xtRePjy_GvJJeU=/2500x/article-new/2023/09/Apple-Watch-Ultra-2-hero-feature-blorange.jpg',
#   'publishedAt': '2024-07-02T13:14:45Z',
#   'content': 'The Apple Watch Ultra 3, likely to be released in September 2024 alongside the iPhone 16, is expected to offer fewer upgrades compared to its predecessor, the Apple Watch Ultra 2. Keep reading to lea… [+3837 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'Apple Seeds Second Beta of tvOS 17.6 to Developers',
#   'description': 'Apple today seeded the second beta of an upcoming tvOS 17.6 to developers for testing purposes, with the second beta coming two weeks after the release of the first beta.\n\n\n\n\n\nRegistered developers are able to download the tvOS 17.6 update by opting in to the…',
#   'url': 'https://www.macrumors.com/2024/07/01/apple-seeds-second-beta-of-tvos-17-6-to-developers/',
#   'urlToImage': 'https://images.macrumors.com/t/E_urDANwhe0J--lgmnYT6INo_ow=/2500x/article-new/2022/07/apple-tv-4k-green.jpg',
#   'publishedAt': '2024-07-01T17:01:00Z',
#   'content': 'Apple today seeded the second beta of an upcoming tvOS 17.6 to developers for testing purposes, with the second beta coming two weeks after the release of the first beta.\r\nRegistered developers are a… [+725 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'Apple Releases Second Beta of visionOS 1.3 to Developers',
#   'description': 'Apple today released the second beta of an upcoming visionOS 1.3 update to developers, allowing them to test new features ahead of the software seeing a public launch. The second \u200cvisionOS\u200c 1.3 beta comes over two weeks after the release of the first beta.\n\n\n…',
#   'url': 'https://www.macrumors.com/2024/07/01/apple-seeds-visionos-1-3-beta-2-to-developers/',
#   'urlToImage': 'https://images.macrumors.com/t/g2mpLo9zAlopoFnItypXQvp7LqY=/1600x/article-new/2023/06/visionos-home-screen-mt-hood.jpg',
#   'publishedAt': '2024-07-01T17:05:00Z',
#   'content': 'Apple today released the second beta of an upcoming visionOS 1.3 update to developers, allowing them to test new features ahead of the software seeing a public launch. The second \u200cvisionOS\u200c 1.3 beta … [+488 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Tim Hardwick',
#   'title': "Apple's Back to School Sale Live in Europe, Asia, and the Middle East",
#   'description': 'Apple today continued with the launch of its annual "Back to School" promotion, debuting back to school deals in most countries in Europe, some countries in Asia, the Middle East, and Mexico.\n\n\n\n\n\nHigher education students and educators in the UK can get up t…',
#   'url': 'https://www.macrumors.com/2024/07/03/apples-back-to-school-sale-launches-europe-asia/',
#   'urlToImage': 'https://images.macrumors.com/t/cPuS3GPj6PXvDafnZzKJLhuqdJY=/1600x/article-new/2024/06/back-to-school-2024.jpg',
#   'publishedAt': '2024-07-03T11:19:18Z',
#   'content': 'Apple today continued with the launch of its annual "Back to School" promotion, debuting back to school deals in most countries in Europe, some countries in Asia, the Middle East, and Mexico.\r\nHigher… [+1373 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'Apple Seeds Second Beta of watchOS 10.6 to Developers',
#   'description': 'Apple today seeded the second beta of an upcoming watchOS 10.6 update to developers for testing purposes, with the second beta coming two weeks after the release of the first beta.\n\n\n\n\n\nTo install the \u200cwatchOS 10.6 update, developers need to open the Apple Wa…',
#   'url': 'https://www.macrumors.com/2024/07/01/apple-seeds-watchos-10-6-beta-2/',
#   'urlToImage': 'https://images.macrumors.com/t/T9LvCyX5TC3cEOOFDRFgVrtLZTs=/1920x/article-new/2023/06/Apple-Watch-Faces-watchOS-10-Feature-Blue.jpg',
#   'publishedAt': '2024-07-01T17:03:00Z',
#   'content': 'Apple today seeded the second beta of an upcoming watchOS 10.6 update to developers for testing purposes, with the second beta coming two weeks after the release of the first beta.\r\nTo install the wa… [+617 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Tim Hardwick',
#   'title': "Here Are the macOS Sequoia Features Intel Macs Won't Support",
#   'description': 'When Apple released macOS Monterey in 2021, some key features required a Mac with Apple silicon. The same scenario played out with macOS Ventura in 2022, and then again the following year with the release of macOS Sonoma. With macOS Sequoia set to arrive in t…',
#   'url': 'https://www.macrumors.com/2024/07/02/macos-sequoia-features-intel-macs-wont-support/',
#   'urlToImage': 'https://images.macrumors.com/t/zZbcqD0-kgQ9SCr6AnSkKJIiULE=/2500x/article-new/2024/06/macOS-Sequoia-Feature.jpg',
#   'publishedAt': '2024-07-02T11:24:17Z',
#   'content': 'When Apple released macOS Monterey in 2021, some key features required a Mac with Apple silicon. The same scenario played out with macOS Ventura in 2022, and then again the following year with the re… [+2297 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Eric Slivka',
#   'title': "Apple's M4 iPad Pro vs. Samsung's Galaxy Tab S9 Ultra",
#   'description': "With the introduction of OLED displays, a thinner design, and more in the M4 iPad Pro, we thought it was worth taking another look at Samsung's flagship OLED tablet, the Galaxy Tab S9 Ultra, to see how the two compare and which one might be the better purchas…",
#   'url': 'https://www.macrumors.com/2024/07/03/m4-ipad-pro-vs-galaxy-tab-s9-ultra/',
#   'urlToImage': 'https://images.macrumors.com/t/vpgV0nxbf9ARSWuTbSrsEdiEoOA=/2500x/article-new/2024/07/Samsung-Tab-S9-Ultra-vs-M4-iPad-Pro-Thumb-2.5.jpg',
#   'publishedAt': '2024-07-03T19:21:58Z',
#   'content': "With the introduction of OLED displays, a thinner design, and more in the M4 iPad Pro, we thought it was worth taking another look at Samsung's flagship OLED tablet, the Galaxy Tab S9 Ultra, to see h… [+3256 chars]"},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'MacBook Owners With Faulty Butterfly Keyboards to Get Payouts Soon',
#   'description': 'Two years after Apple paid $50 million to settle a class-action lawsuit over faulty MacBook butterfly keyboards, funds from the settlement will be going out to affected customers.\n\n\n\n\n\nAn update on the MacBook Keyboard Litigation Settlement website says that …',
#   'url': 'https://www.macrumors.com/2024/07/01/macbook-pro-butterfly-keyboard-payout/',
#   'urlToImage': 'https://images.macrumors.com/t/GGCpb1upY4KqruKd9gC6UTH2bYo=/1955x/article-new/2021/03/macbook-pro-butterfly-keyboard.jpg',
#   'publishedAt': '2024-07-01T20:09:52Z',
#   'content': 'Two years after Apple paid $50 million to settle a class-action lawsuit over faulty MacBook butterfly keyboards, funds from the settlement will be going out to affected customers.\r\nAn update on the M… [+1600 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Tim Hardwick',
#   'title': "iPhone 16 Pro Models to Adopt 'M14' Advanced Samsung OLED Panels for Improved Brightness and Lifespan",
#   'description': 'The upcoming iPhone 16 Pro and iPhone 16 Pro Max will be the first Apple smartphones to adopt Samsung\'s high performance "M14" OLED display panel, claims a new report coming out of South Korea.\n\n\n\n\n\nAccording to ETNews, Samsung\'s "M" series of OLED panels are…',
#   'url': 'https://www.macrumors.com/2024/07/01/iphone-16-pro-max-advanced-oled-display/',
#   'urlToImage': 'https://images.macrumors.com/t/xcTabKWMzOGvrlv91McWob6xGn0=/2000x/article-new/2024/06/iPhone-16-Pro-Front-Update-Blue.jpg',
#   'publishedAt': '2024-07-01T09:52:52Z',
#   'content': 'The upcoming iPhone 16 Pro and iPhone 16 Pro Max will be the first Apple smartphones to adopt Samsung\'s high performance "M14" OLED display panel, claims a new report coming out of South Korea.\r\nAcco… [+1620 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Eric Slivka',
#   'title': 'Amazon and Best Buy Take Up to $500 Off on Latest MacBook Pro Models',
#   'description': 'Amazon and Best Buy have introduced record discounts on the latest 14-inch and 16-inch MacBook Pro models today, taking up to $500 off of standard prices.\n\n\n\nNote: MacRumors is an affiliate partner with Amazon and Best Buy. When you click a link and make a pu…',
#   'url': 'https://www.macrumors.com/2024/07/03/amazon-best-buy-macbook-pro-500-off/',
#   'urlToImage': 'https://images.macrumors.com/t/ALQ_JQLdgAVXTj9Iq25ykN3G1Kk=/2500x/article-new/2024/06/m3-macbook-pro-blue.jpg',
#   'publishedAt': '2024-07-03T14:14:24Z',
#   'content': 'Amazon and Best Buy have introduced record discounts on the latest 14-inch and 16-inch MacBook Pro models today, taking up to $500 off of standard prices.\r\nNote: MacRumors is an affiliate partner wit… [+1405 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Aashna Gheewalla',
#   'title': "Don't Wait for Prime Day. 42 Amazon July 4th Deals Worth Buying Right Now",
#   'description': 'Make the most of these July 4th deals and snag the best prices on Apple products, smart home gear, TVs, appliances and more.',
#   'url': 'https://www.cnet.com/deals/amazon-july-4th-sale-2024-07-04/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/598684421bea2d892cdfae8b5207c797cc751952/hub/2024/06/27/b7a14e3e-d556-48b2-bedb-95f0e521ed97/amaozn-july-4-sale.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-04T09:34:46Z',
#   'content': "Ring/Apple/Samsung/CNET\r\nDon't skip the Fourth of July\xa0deals happening at Amazon right now. The retailer has hundreds of special deals and early Prime Day discounts\xa0that are live already, making it a… [+1295 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Matt Poskitt',
#   'title': 'Best July 4th Laptop Sales: Jaw-Dropping Discounts on Apple, HP, Lenovo and More',
#   'description': "The Fourth of July is here and so are some of the biggest discounts we've seen on top-rated laptops at Amazon, Best Buy and elsewhere.",
#   'url': 'https://www.cnet.com/deals/july-4th-laptop-deals-2024-07-04/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/fc996571648630bf56c37b3f4b51f0f34ff078c9/hub/2024/06/25/5e8552b7-0219-4edd-a4c9-f1b482e614f6/laptop-fourth-of-july-2024-commerce-image.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-04T13:46:48Z',
#   'content': "HP/Apple/CNET\r\nWhether you're a student or a professional, getting a new laptop is an investment and Fourth of July sales\xa0can make your dollar stretch a little further. Since today is the official Fo… [+5039 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Adrian Marlow',
#   'title': "Get 20% Off Tech Accessories With Journey's Fourth of July Sale",
#   'description': 'Cue the fireworks: Journey is giving 20% off on countless tech accessories for the Fourth of July.',
#   'url': 'https://www.cnet.com/deals/get-20-off-tech-accessories-for-journeys-fourth-of-july-sale/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/feab3476a93eacbeeb53496703b29edee5f82589/hub/2024/07/01/2e5aab9c-8c60-4430-9ab1-78b949292672/journeys-july4.png?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-01T18:40:00Z',
#   'content': 'The Fourth of July is just a few days away and the deals are flowing in. Journey, which is known for their high quality\xa0battery packs, USB charger\xa0and other tech accessories, is having a huge sitewid… [+850 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Aashna Gheewalla',
#   'title': '57 Sizzling Hot July 4th Deals Under $25: Bargain Prices on Tech, Toys, Outdoor and Home Essentials',
#   'description': "The July 4th discounts abound, but don't wait because these offers may end with the fireworks display.",
#   'url': 'https://www.cnet.com/deals/july-4th-deals-under-25-2024-07-04/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/abb1bfcae0aa26c9890f2439dc597cd888a2e652/hub/2024/06/28/d009d152-a215-49c3-b692-85a0e76649c3/july4-under-25.png?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-04T09:22:00Z',
#   'content': 'If you can smell fireworks and barbecue, it must be Independence Day. That means\xa0Fourth of July sales\xa0are reaching their peak. While it can be tempting to spend lots of cash during these shopping eve… [+4332 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Matt Poskitt',
#   'title': 'Best Fourth of July Laptop Deals: Save on MacBooks, Windows PCs, Chromebooks and More',
#   'description': 'Score big savings on some of the best laptops at Amazon, Walmart and Target this Fourth of July.',
#   'url': 'https://www.cnet.com/deals/best-fourth-of-july-laptop-deals-2024-07-01/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/fc996571648630bf56c37b3f4b51f0f34ff078c9/hub/2024/06/25/5e8552b7-0219-4edd-a4c9-f1b482e614f6/laptop-fourth-of-july-2024-commerce-image.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-02T00:52:00Z',
#   'content': 'HP/Apple/CNET\r\nWhether for gaming or work, a new laptop can go a long way in improving your experience and productivity.\xa0Fourth of July sales\xa0might be the perfect time to get a new device without hav… [+4477 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Amanda Smith',
#   'title': 'How to Use ChatGPT to Find the Best Deals and Coupons',
#   'description': "If you've got ChatGPT Pro, then your AI tool has access to the internet -- and you can use it to find you some sweet shopping deals.",
#   'url': 'https://www.cnet.com/tech/services-and-software/how-to-use-chatgpt-to-find-the-best-deals-and-coupons/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/01ac917af8c3e6c134ae0728ac2d4fb42217b482/hub/2024/07/01/9b61d785-9e0e-4e09-bea0-1365c4fc673e/gettyimages-2003135108.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-03T12:30:04Z',
#   'content': "Whether you shop online or love a trip to the mall for a dose of childhood nostalgia, you're probably looking to score the best sales. In the current economy, every dollar counts, and using artificia… [+4100 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Adrian Marlow',
#   'title': 'Get Yourself a 65-Inch 4K TV for Just $300 Thanks to This July 4th Deal',
#   'description': 'Make the most of this July 4th deal and save $150 on this excellent TV.',
#   'url': 'https://www.cnet.com/deals/get-yourself-65-inch-4k-tv-just-300-thanks-to-july-4th-deal/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/bd8a6d76cd595415a6fdd00bd1b684e9d3fd95eb/hub/2024/07/02/2b10c680-765a-4cc0-b2b4-450e108c8b1e/insignia-fourth-july-sale.png?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-04T12:45:46Z',
#   'content': "If you've been considering upgrading your TV,\xa0Fourth of July sales are an excellent time take the leap and save a little cash. Those who want to get a great\xa04K TV\xa0while saving a fair bit of money sho… [+1093 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Ian Sherr',
#   'title': 'Samsung Reportedly Trying to Take Down Galaxy Z Fold 6, Z Flip 6 Images Ahead of Unpacked',
#   'description': "Samsung's latest leaks came a little over a week before the devices are expected to be announced.",
#   'url': 'https://www.cnet.com/tech/mobile/samsung-reportedly-trying-to-take-down-galaxy-z-fold-6-z-flip-6-images-ahead-of-unpacked/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/38b169c5ee4931da54591ca4441efe156929b502/hub/2023/08/07/2f4b1939-686a-4114-9032-a467046ecbe3/z-flip-5-review-7.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-01T20:56:59Z',
#   'content': "We're just days away from Samsung Galaxy Unpacked on July 10, and the tech giant has now come about as close as possible to pre-announcing its news -- by sending reported takedown requests to the X s… [+2227 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Omar Gallaga',
#   'title': 'Report Suggests Pixel 9 Will Introduce Google AI to Smartphones',
#   'description': "One reported feature could be similar to Microsoft's much-criticized Recall, which the company pulled from a recent hardware release.",
#   'url': 'https://www.cnet.com/tech/mobile/report-suggests-pixel-9-will-introduce-google-ai-to-smartphones/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/610c41026762f21a76c1863180b4cdb467d08dd5/hub/2024/04/16/c00e4bbc-a63a-4d2f-8b25-4c2f3569b939/ai-atlas-tag.png?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-02T16:42:00Z',
#   'content': "The new battleground for smartphone features is apparently large-language-model intelligence. And, according to a new report, Google's big AI salvo will launch next month with the upcoming PIxel 9 sm… [+2161 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Ian Sherr',
#   'title': 'Meta Is Changing Artificial Intelligence Labels After Real Photos Were Marked As AI',
#   'description': 'Advanced editing software is blurring the lines between real and AI-generated posts.',
#   'url': 'https://www.cnet.com/tech/services-and-software/meta-is-changing-artificial-intelligence-labels-after-real-photos-were-marked-as-ai/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/83cd2ef109097449f6b863f6d83b28f8d4e3a7e8/hub/2024/05/15/2f48a1aa-8d66-4768-9939-f3070cb04fec/gettyimages-1481133084-2.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-01T22:00:09Z',
#   'content': 'Meta is changing the labels it applies to social media posts suspected to have been generated in some way with artificial intelligence tools. The Facebook, Instagram, Threads and WhatsApp parent comp… [+2739 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Katie Collins',
#   'title': "Google's Rising Emissions Lay the Climate Impact of AI Bare",
#   'description': "Commentary: Google's greenhouse gas emissions have grown almost 50% since 2019. It says AI is to blame.",
#   'url': 'https://www.cnet.com/tech/services-and-software/googles-rising-emissions-lay-the-climate-impact-of-ai-bare/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/36d44ac1077d8804d01340c33088d29981f1710d/hub/2019/10/09/c4c3396e-df9e-40ad-9f77-448dcf02bdb6/20191008-google-headquarters-campus-mountain-view-001.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-04T12:40:26Z',
#   'content': "Google is falling so short of its climate goals that in some respects it's going backwards. In the company's 2024 Environmental Report, which came out this week, Google was forced to admit that its g… [+4651 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Gael Cooper',
#   'title': "Today's Wordle Hints, Answer and Help for July 1, #1108",
#   'description': "Here's today's Wordle answer, plus a look at spoiler-free hints and past solutions. These clues will help you solve New York Times' popular puzzle game, Wordle, every day!",
#   'url': 'https://www.cnet.com/tech/gaming/todays-wordle-hints-answer-and-help-for-july-1-1108/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/592e28315757d67fe06917f7250e031fcfff808e/hub/2024/04/30/77eed7a6-020b-40f8-b23e-aed247f34865/word-games-wordle-ny-times-9494.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-07-01T03:00:08Z',
#   'content': "Today's Wordle answer might be a tough one, so scroll on if you're stumped. Every day, we post hints and then the answer for the current day's Wordle, just in case you need it.\r\nAlso, we've\xa0ranked al… [+3670 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'David McMillin',
#   'title': 'Watch Out for These Devious Banking Scams',
#   'description': "Scammers stole more than $10 billion from consumers last year. Here's how to keep their hands off your hard-earned dollars.",
#   'url': 'https://www.cnet.com/personal-finance/banking/advice/watch-out-for-these-devious-banking-scams/',
#   'urlToImage': 'https://www.cnet.com/personal-finance/assets/uploads/resize/2534b7d84edaa3cfec87950ba8e073e9b4e6d0dd/m1/2024/06/GettyImages-1294404547.jpg?auto=webp',
#   'publishedAt': '2024-07-02T20:49:00Z',
#   'content': 'You know you shouldn’t send money to a Nigerian prince online. But scammers have plenty of other schemes up their sleeves, and they’re not all so easy to spot.\r\nLast year alone, consumers lost $10 bi… [+7726 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Hartley Charlton',
#   'title': "Apple Reclassifies iPhone X, HomePod, and Original AirPods as 'Vintage'",
#   'description': 'Apple today reclassified the iPhone X, first-generation HomePod, and first-generation AirPods as "vintage" products.\n\n\n\n\n\nThe products appeared on Apple\'s vintage and obsolete products list earlier today. Products are considered vintage when Apple stopped dis…',
#   'url': 'https://www.macrumors.com/2024/07/01/iphone-x-homepod-and-original-airpods-now-vintage/',
#   'urlToImage': 'https://images.macrumors.com/t/3inxtG6rSW98CAKR1aOmWL_GYRM=/2144x/article-new/2021/03/homepod-feature-blue2.jpg',
#   'publishedAt': '2024-07-01T14:52:39Z',
#   'content': 'Apple today reclassified the iPhone X, first-generation HomePod, and first-generation AirPods as "vintage" products.\r\nThe products appeared on Apple\'s vintage and obsolete products list earlier today… [+2887 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': "Apple's Phil Schiller to Serve as OpenAI Board Observer as Part of iOS 18 AI Agreement",
#   'description': 'Apple Fellow and App Store chief Phil Schiller will take on a board observer position at OpenAI, reports Bloomberg. Apple has been granted an observer role as part of its agreement with OpenAI, which will see ChatGPT integrated into iOS 18, iPadOS 18, and mac…',
#   'url': 'https://www.macrumors.com/2024/07/02/apple-schiller-openai-board-observer/',
#   'urlToImage': 'https://images.macrumors.com/t/7dsbIaosd3Op153XpVVz5XfY258=/1600x/article-new/2024/06/open-ai-logo.jpg',
#   'publishedAt': '2024-07-02T21:14:05Z',
#   'content': 'Apple Fellow and App Store chief Phil Schiller will take on a board observer position at OpenAI, reports Bloomberg. Apple has been granted an observer role as part of its agreement with OpenAI, which… [+1109 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Hartley Charlton',
#   'title': 'iPhone and Apple Watch Likely to Support NFC Multi-Purpose Tap in the Future',
#   'description': 'iPhones and Apple Watches could support multiple actions via NFC simultaneously in the future, the NFC Forum today suggested.\n\n\n\n\n\nThe NFC Forum, the leading standards body for Near Field Communication (NFC) technology, today published its first overview of N…',
#   'url': 'https://www.macrumors.com/2024/07/01/iphone-likely-to-support-nfc-multi-purpose-tap/',
#   'urlToImage': 'https://images.macrumors.com/t/VMWaZYQyQr5u14pdxbF2A5KZ6YM=/1600x/article-new/2022/04/apple-card-via-apple-pay.jpeg',
#   'publishedAt': '2024-07-01T15:43:03Z',
#   'content': 'iPhones and Apple Watches could support multiple actions via NFC simultaneously in the future, the NFC Forum today suggested.\r\nThe NFC Forum, the leading standards body for Near Field Communication (… [+1305 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'Apple Seeds Second Betas of iOS 17.6 and iPadOS 17.6 to Developers',
#   'description': 'Apple today seeded the second betas of upcoming iOS 17.6 and iPadOS 17.6 updates to developers for testing purposes, with the second betas coming two weeks after the first iOS and iPadOS 17.6 betas.\n\n\n\n\n\nRegistered developers are able to opt into the betas by…',
#   'url': 'https://www.macrumors.com/2024/07/01/apple-seeds-ios-17-6-beta-2-to-developers/',
#   'urlToImage': 'https://images.macrumors.com/t/yYLRf7x6pc4u28bqp35Q20qvBYk=/2500x/article-new/2024/05/iOS-17.6-Feature-Redux.jpg',
#   'publishedAt': '2024-07-01T17:08:19Z',
#   'content': 'Apple today seeded the second betas of upcoming iOS 17.6 and iPadOS 17.6 updates to developers for testing purposes, with the second betas coming two weeks after the first iOS and iPadOS 17.6 betas.\r… [+616 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'Apple Leak Confirms Four iPhone 16 Models With Same A18 Chip',
#   'description': "Code discovered in Apple's backend by Nicolás Alvarez and shared with MacRumors confirms Apple's plans to release four iPhone 16 models this year, and it indicates that the devices will all have the same A-series chip. There are mentions of new model numbers …",
#   'url': 'https://www.macrumors.com/2024/07/02/iphone-16-models-a18-chip/',
#   'urlToImage': 'https://images.macrumors.com/t/ELATlCHNQAuJsQdzmAXou9Z1QGA=/2500x/article-new/2024/02/iPhone-16-Camera-Lozenge-2.jpg',
#   'publishedAt': '2024-07-02T16:48:06Z',
#   'content': "Code discovered in Apple's backend by Nicolás Alvarez and shared with MacRumors confirms Apple's plans to release four iPhone 16 models this year, and it indicates that the devices will all have the … [+2720 chars]"},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Eric Slivka',
#   'title': 'Resident Evil 7 Debuts on iPhone 15 Pro, iPad, and Mac',
#   'description': "As part of its effort to embrace Apple's latest chips, Capcom today released Resident Evil 7 biohazard for iPhone 15 Pro, \u200ciPhone 15 Pro\u200c Max, and all iPads and Macs with M-series Apple silicon chips. [App Store]\n\n\n\n\r\n\n\nThe game runs natively on Apple silicon…",
#   'url': 'https://www.macrumors.com/2024/07/02/resident-evil-7-iphone-15-pro-ipad-mac/',
#   'urlToImage': 'https://images.macrumors.com/t/Nn3XEluTdcDqzsXNweNCGWUAqx0=/1600x/article-new/2024/07/resident-evil-7.jpg',
#   'publishedAt': '2024-07-02T16:14:00Z',
#   'content': "As part of its effort to embrace Apple's latest chips, Capcom today released Resident Evil 7 biohazard for iPhone 15 Pro, \u200ciPhone 15 Pro\u200c Max, and all iPads and Macs with M-series Apple silicon chips… [+1080 chars]"},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'iOS 18: 10 New Home Screen and Lock Screen Features',
#   'description': 'With iOS 18, Apple overhauled the Home Screen, introducing design changes that allow for more customization and personalization. You can put icons where you want, change their size, and give them new colors, plus you can hide apps and swap out your Lock Scree…',
#   'url': 'https://www.macrumors.com/guide/ios-18-home-screen/',
#   'urlToImage': 'https://images.macrumors.com/t/hJEn_yKnruwj5bWxqQR1voGytxI=/2500x/article-new/2024/07/iOS-18-Home-Screen-Feature-2.jpg',
#   'publishedAt': '2024-07-02T22:45:35Z',
#   'content': 'With iOS 18, Apple overhauled the Home Screen, introducing design changes that allow for more customization and personalization. You can put icons where you want, change their size, and give them new… [+12165 chars]'},
#  {'source': {'id': None, 'name': 'NPR'},
#   'author': 'Andee Tagle',
#   'title': 'Ready to combine finances with your partner? You have options',
#   'description': 'First comes love ... then comes money management discussions? Financial therapist Lindsay Bryan-Podvin discusses three common approaches that couples use to merge their money.',
#   'url': 'https://www.npr.org/2024/07/01/g-s1-7478/how-to-combine-finances-with-your-partner',
#   'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/599x337+0+0/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F98%2F30%2F01c57b1149e789eada62c85421fc%2Fgettyimages-1294710830-wide-5b582badacb7497872af5bcf5cd806a55ab430b8.jpg',
#   'publishedAt': '2024-07-01T15:43:53Z',
#   'content': 'If youre in a serious romantic relationship, you and your partner may be thinking about how to combine your finances. Should you share a joint bank account? Keep your accounts separate? Do a combinat… [+4969 chars]'},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'BeauHD',
#   'title': "Phil Schiller To Join OpenAI Board In 'Observer' Role Following Apple's ChatGPT Deal",
#   'description': 'As reported by Bloomberg, Apple will get an "observer role" on OpenAI\'s board of directors as part of its partnership to integrate ChatGPT into iOS 18. That role will reportedly be filled by Apple Fellow, Phil Schiller. 9to5Mac reports: Apple having an "obser…',
#   'url': 'https://apple.slashdot.org/story/24/07/02/2226256/phil-schiller-to-join-openai-board-in-observer-role-following-apples-chatgpt-deal',
# ...
#   'publishedAt': '2024-07-02T21:40:00Z',
#   'content': 'A medida que nos acercamos a septiembre, son cada vez más los rumores sobre las características del iPhone 16. En esta nueva oportunidad, una filtración reportada por MacRumors afirma que todos los m… [+3202 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Gabriel Erard',
#   'title': '‘Fortnite’ queda a un paso de regresar al iPhone',
#   'description': 'Epic Games ha dado un paso crucial para el regreso de Fortnite al iPhone. La compañía anunció el envío del popular juego y de la Epic Games Store al proceso de notarización de Apple para el arribo de ambos a iOS/iPadOS. El estudio espera que el próximo paso s…',
#   'url': 'http://hipertextual.com/2024/07/fortnite-queda-a-un-paso-de-regresar-al-iphone',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2021/08/fortnite-scaled.jpg',
#   'publishedAt': '2024-07-01T18:57:50Z',
#   'content': 'Epic Games ha dado un paso crucial para el regreso de Fortnite al iPhone. La compañía anunció el envío del popular juego y de la Epic Games Store al proceso de notarización de Apple para el arribo de… [+3427 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Quelian Sanz',
#   'title': 'Filtradas dos novedades de iOS 18 para una de las apps más utilizadas del iPhone',
#   'description': 'La WWDC 2024 no fue la encargada de revelar absolutamente todo sobre iOS 18 y el resto de sistemas operativos de Apple. Poco a poco, ahora que las betas están en marcha, se van desgranando más detalles que llegarán a todos los rincones de la versión final. De…',
#   'url': 'http://hipertextual.com/2024/07/filtradas-dos-novedades-de-ios-18-para-una-de-las-apps-mas-utilizadas-del-iphone',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2024/06/ios-18-iphone.jpg',
#   'publishedAt': '2024-07-04T07:23:32Z',
#   'content': 'La WWDC 2024 no fue la encargada de revelar absolutamente todo sobre iOS 18 y el resto de sistemas operativos de Apple. Poco a poco, ahora que las betas están en marcha, se van desgranando más detall… [+3151 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Rubén Chicharro',
#   'title': 'Este cambio va a hacer que los iPhone 16 tengan más batería y sean más fáciles de reparar',
#   'description': 'A principios de año, un rumor revelaba que los iPhone 16 contarían con una batería de mayor capacidad, incrementando hasta en un 16 % su tamaño gracias a un nuevo diseño del componente, que tendría una forma de L. Ahora, una nueva filtración detalla que los p…',
#   'url': 'http://hipertextual.com/2024/07/este-cambio-va-a-hacer-que-los-iphone-16-tengan-mas-bateria-y-sean-mas-faciles-de-reparar',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2024/02/camara-iphone-16.jpg',
#   'publishedAt': '2024-07-01T12:14:29Z',
#   'content': 'A principios de año, un rumor revelaba que los iPhone 16 contarían con una batería de mayor capacidad, incrementando hasta en un 16 % su tamaño gracias a un nuevo diseño del componente, que tendría u… [+2290 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Aglaia Berlutti',
#   'title': '‘Tierra de mujeres’, la producción española encabezada por Eva\xa0Longoria que tienes que ver',
#   'description': 'Durante la última década, Apple TV+ no ha hecho más que crecer. De comenzar con un catálogo, si se quiere discreto y enfocado en la ciencia ficción, su evolución le lleva ahora a nuevos terrenos. Lo que incluye la comedia y producciones internacionales. Una d…',
#   'url': 'http://hipertextual.com/2024/07/tierra-de-mujeres-la-produccion-espanola-encabezada-por-eva-longoria-que-tienes-que-ver',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2024/04/tierra-mujeres-scaled.jpg',
#   'publishedAt': '2024-07-02T09:16:28Z',
#   'content': 'Durante la última década, Apple TV+ no ha hecho más que crecer. De comenzar con un catálogo, si se quiere discreto y enfocado en la ciencia ficción, su evolución le lleva ahora a nuevos terrenos. Lo … [+4815 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Luis Miranda',
#   'title': 'Millones de iPhones quedaron expuestos a vulnerabilidades críticas durante una década',
#   'description': 'Expertos en seguridad descubrieron tres vulnerabilidades críticas que pusieron en riesgo a millones de iPhones y Mac por casi una década. Un fallo en CocoaPods, un proyecto de código abierto para agilizar el desarrollo de aplicaciones, abrió la puerta a ataqu…',
#   'url': 'http://hipertextual.com/2024/07/millones-de-iphones-expuestos-vulnerabilidades-criticas-decada',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2024/02/william-hook-9e9PD9blAto-unsplash-1-scaled.jpg',
#   'publishedAt': '2024-07-02T19:32:38Z',
#   'content': 'Expertos en seguridad descubrieron tres vulnerabilidades críticas que pusieron en riesgo a millones de iPhones y Mac por casi una década. Un fallo en CocoaPods, un proyecto de código abierto para agi… [+3350 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Rubén Chicharro',
#   'title': 'La UE acusa a Meta de violar la Ley de Mercados Digitales',
#   'description': 'La Unión Europea está a punto de acusar a Meta por violar la Ley de Mercados Digitales (DMA, por sus siglas en inglés), que obliga a las grandes compañías a cumplir una serie de medidas para evitar prácticas monopolísticas, que puedan perjudicar a los usuario…',
#   'url': 'http://hipertextual.com/2024/07/la-ue-acusa-a-meta-de-violar-la-ley-de-mercados-digitales',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2024/05/zuckerberg-meta.jpg',
#   'publishedAt': '2024-07-01T07:36:40Z',
#   'content': 'La Unión Europea está a punto de acusar a Meta por violar la Ley de Mercados Digitales (DMA, por sus siglas en inglés), que obliga a las grandes compañías a cumplir una serie de medidas para evitar p… [+2528 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Quelian Sanz',
#   'title': 'AliExpress tira el precio del iPhone 15 y lo convierte en un chollo',
#   'description': 'AliExpress tenía programada para hoy su campaña Big Save Day, una de las más interesantes si lo que buscas son productos tecnológicos. No hemos podido resistirnos a darnos una vuelta por su catálogo para contarte qué ofertas son las más interesantes. Y, como …',
#   'url': 'http://hipertextual.com/2024/07/aliexpress-tira-el-precio-del-iphone-15-y-lo-convierte-en-un-chollo',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2023/09/iPhone-15-7-scaled.jpg',
#   'publishedAt': '2024-07-04T12:52:13Z',
#   'content': 'AliExpress tenía programada para hoy su campaña Big Save Day, una de las más interesantes si lo que buscas son productos tecnológicos. No hemos podido resistirnos a darnos una vuelta por su catálogo … [+2557 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Quelian Sanz',
#   'title': 'El Google Pixel 9 se filtra en un color de lo más inesperado',
#   'description': 'Ahora que Google ha anunciado la fecha de presentación del Pixel 9 y el Pixel Watch 3 las filtraciones están llegando casi a diario. Hoy toma el protagonismo el próximo smartphone de su catálogo, que según un usuario argelino, llegará en un color de lo más ra…',
#   'url': 'http://hipertextual.com/2024/07/el-google-pixel-9-se-filtra-en-un-color-de-lo-mas-inesperado',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2024/07/Google-pixel-9-1.jpg',
#   'publishedAt': '2024-07-02T07:18:22Z',
#   'content': 'Ahora que Google ha anunciado la fecha de presentación del Pixel 9 y el Pixel Watch 3 las filtraciones están llegando casi a diario. Hoy toma el protagonismo el próximo smartphone de su catálogo, que… [+2886 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'Gabriel Erard',
#   'title': 'Skoda Elroq: así es el nuevo SUV compacto eléctrico, con hasta 560 km de autonomía que le planta cara al Renault 5',
#   'description': 'Skoda ha revelado las principales características del Elroq, su nuevo SUV compacto 100 % eléctrico. El nuevo coche de la marca perteneciente al Grupo Volkswagen traerá un diseño muy atractivo y prestaciones más que suficientes para sacarle provecho tanto dent…',
#   'url': 'http://hipertextual.com/2024/07/skoda-elroq-caracteristicas-lanzamiento',
#   'urlToImage': 'https://imgs.hipertextual.com/wp-content/uploads/2024/07/el-skoda-elroq-totalmente-electrico-1-scaled.jpg',
#   'publishedAt': '2024-07-01T14:39:47Z',
#   'content': 'Skodaha revelado las principales características del Elroq, su nuevo SUV compacto 100 % eléctrico. El nuevo coche de la marca perteneciente al Grupo Volkswagen traerá un diseño muy atractivo y presta… [+4370 chars]'},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'Ioanna Lykiardopoulou',
#   'title': 'Meta’s ‘pay or consent’ model in breach of EU tech rules, says Brussels',
#   'description': 'In yet another blow to big tech, the EU is charging Meta with breaching the bloc’s sweeping online competition rules, known as the Digital Markets Act (DMA). Alongside Google and Apple, Meta is among the tech giants (designated as “gatekeepers“) required to c…',
#   'url': 'https://thenextweb.com/news/metas-pay-or-consent-model-breach-eu-tech-rules',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/tnw-blurple?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2023%2F07%2FUntitled-design-6-4.jpg&signature=16aa807d3fe3cdbde9cb369f7ede8cae',
#   'publishedAt': '2024-07-01T13:05:14Z',
#   'content': 'In yet another blow to big tech, the EU is charging Meta with breaching the blocs sweeping online competition rules, known as the Digital Markets Act (DMA).\r\nAlongside Google and Apple, Meta is among… [+2084 chars]'},
#  {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#   'author': 'Andrii Degeler',
#   'title': 'TNW Podcast: From satellite tracking and space regulation to multimodal AI, and more',
#   'description': 'Welcome to the new episode of the TNW Podcast — the show where we discuss the latest developments in the European technology ecosystem and feature interviews with some of the most interesting people in the industry. In today’s episode, we’re featuring two int…',
#   'url': 'https://thenextweb.com/news/satellite-tracking-space-regulation-multimodal-ai',
#   'urlToImage': 'https://img-cdn.tnwcdn.com/image/tnw-blurple?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2024%2F06%2Ftnw-podcast-feat-gimp.jpg&signature=f2f8403a596c92e0062e2c007746c222',
#   'publishedAt': '2024-07-03T10:55:00Z',
#   'content': 'Welcome to the new episode of the TNW Podcast the show where we discuss the latest developments in the European technology ecosystem and feature interviews with some of the most interesting people in… [+715 chars]'},
#  {'source': {'id': None, 'name': 'Hackaday'},
#   'author': 'Arya Voronova',
#   'title': 'USB And The Myth Of 500 Milliamps',
#   'description': 'If you’re designing a universal port, you will be expected to provide power. This was a lesson learned in the times of LPT and COM ports, where factory-made peripherals and DIY boards alike h…',
#   'url': 'https://hackaday.com/2024/07/03/usb-and-the-myth-of-500-milliamps/',
#   'urlToImage': 'https://hackaday.com/wp-content/uploads/2024/04/usb-featured.jpg',
#   'publishedAt': '2024-07-03T17:00:01Z',
#   'content': 'If you’re designing a universal port, you will be expected to provide power. This was a lesson learned in the times of LPT and COM ports, where factory-made peripherals and DIY boards alike had to pu… [+9548 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Josh Lipton',
#   'title': "Roaring Kitty lawsuit, GDP forecasts dip: Monday's market trends",
#   'description': 'Yahoo Finance Reporter Josh Schafer joins Asking for a Trend to discuss his key takeaways from the trading day. The Nasdaq Composite (^IXIC) hit a record...',
#   'url': 'https://finance.yahoo.com/video/roaring-kitty-lawsuit-gdp-forecasts-214731303.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/X35nbQ9PzBBHK54sYGsxQQ--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02NzU-/https://s.yimg.com/os/creatr-uploaded-images/2024-07/db6e2710-37f1-11ef-bf79-4e232f23a050',
#   'publishedAt': '2024-07-01T21:47:31Z',
#   'content': "Yahoo Finance Reporter Josh Schafer joins Asking for a Trend to discuss his key takeaways from the trading day.\r\nThe Nasdaq Composite (^IXIC) hit a record high in Monday's session despite a higher mo… [+7996 chars]"},
#  {'source': {'id': None, 'name': 'Slate Magazine'},
#   'author': 'Mary Harris',
#   'title': 'How Bad is the Trump Immunity Ruling?',
#   'description': 'Looking for “alternate electors”? Telling your VP to throw out votes? Whipping a crowd into a riotous frenzy? Official acts, and therefore: immune.',
#   'url': 'https://slate.com/podcasts/what-next/2024/07/how-the-supreme-court-gave-trump-immunity',
#   'urlToImage': 'https://compote.slate.com/images/cdecb6c8-034a-4c4f-ac1e-04a8f994c66b.jpeg?crop=4500%2C3000%2Cx0%2Cy0&width=1560',
#   'publishedAt': '2024-07-02T09:00:00Z',
#   'content': 'The Supreme Court has ruled that presidents enjoy substantial immunity from prosecution for crimes committed while in office, which includes absolute immunity for core constitutional duties and presu… [+619 chars]'},
#  {'source': {'id': None, 'name': 'Slate Magazine'},
#   'author': 'Celeste Headlee',
#   'title': 'Federal Job Training Doesn’t Work',
#   'description': 'High-demand jobs might not be in demand because they’re good jobs.',
#   'url': 'https://slate.com/podcasts/hearmeout/2024/07/workforce-training-programs-dont-work',
#   'urlToImage': 'https://compote.slate.com/images/63f911a6-227f-4d00-8883-a2e757cc7de8.jpeg?crop=1560%2C1040%2Cx0%2Cy0&width=1560',
#   'publishedAt': '2024-07-02T09:00:00Z',
#   'content': 'On todays episode of Hear Me Out: get back to work.\r\nWhen your job becomes obsolete, is it the governments job to teach you to do something else?\r\nThats the theory behind federal workforce training p… [+748 chars]'},
#  {'source': {'id': 'espn', 'name': 'ESPN'},
#   'author': 'Michael Voepel',
#   'title': 'Midseason grades for all 12 WNBA teams: Why Liberty, Lynx and Sun get high marks',
#   'description': 'Grades are in, starting with one A+ on our WNBA report card halfway through the regular season. But seven teams got a C+ or worse, including one F.',
#   'url': 'https://www.espn.com/wnba/story/_/id/40488913/wnba-2024-midseason-grades-report-card-every-team-winners-losers',
#   'urlToImage': 'https://a.espncdn.com/combiner/i?img=%2Fphoto%2F2024%2F0704%2Fr1354233_1296x729_16%2D9.jpg',
#   'publishedAt': '2024-07-04T12:35:08Z',
#   'content': "The WNBA team in the Big Apple is at the top of the class. The two-time defending champion is above average. And a playoff team from last season needs study hall.\r\nWith the league's 12 teams at or ne… [+9243 chars]"},
#  {'source': {'id': None, 'name': 'Xataka.com'},
#   'author': 'Javier Marquez',
#   'title': 'La apuesta de Apple por la inteligencia artificial está incomodando a algunos de sus usuarios más fieles: los creativos',
#   'description': 'El pasado 10 de junio en la WWDC 2024 Apple dio a conocer su apuesta por la inteligencia artificial (IA). La firma liderada por Tim Cook presentó Apple Intelligence, un sistema que aterrizará iOS 18, iPadOS 18 y macOS 15 Sequoia para permitir a los usuarios d…',
#   'url': 'https://www.xataka.com/robotica-e-ia/apuesta-apple-inteligencia-artificial-esta-incomodando-a-algunos-sus-usuarios-fieles-creativos',
#   'urlToImage': 'https://i.blogs.es/e0d851/1urban_sketchers_uma_kelkar_outdoor_illustration_20171127_big_large_2x/840_560.jpeg',
#   'publishedAt': '2024-07-03T20:46:23Z',
#   'content': 'El pasado 10 de junio en la WWDC 2024 Apple dio a conocer su apuesta por la inteligencia artificial (IA). La firma liderada por Tim Cook presentó Apple Intelligence, un sistema que aterrizará iOS 18,… [+2926 chars]'}]
