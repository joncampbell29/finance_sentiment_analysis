# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os

# %%
load_dotenv()
key = os.getenv("FRED_API_KEY")

# %%
url = f"https://api.stlouisfed.org/fred/series?series_id=GDP&api_key={key}&file_type=json"
url = f"https://api.stlouisfed.org/fred/series/vintagedates?series_id=GNPCA&api_key={key}&file_type=json"

# %%
resp=requests.get(url)

# %%
resp.json()
# Out:
# {'realtime_start': '1776-07-04',
#  'realtime_end': '9999-12-31',
#  'order_by': 'vintage_date',
#  'sort_order': 'asc',
#  'count': 184,
#  'offset': 0,
#  'limit': 10000,
#  'vintage_dates': ['1958-12-21',
#   '1959-02-19',
#   '1959-07-19',
#   '1960-02-16',
#   '1960-07-22',
#   '1961-02-19',
#   '1961-07-19',
#   '1962-02-24',
#   '1962-07-20',
#   '1963-02-20',
#   '1963-07-22',
#   '1964-02-20',
#   '1964-07-16',
#   '1965-01-14',
#   '1965-02-17',
#   '1965-08-19',
#   '1966-01-13',
#   '1966-02-15',
#   '1966-07-15',
#   '1967-01-13',
#   '1967-02-17',
#   '1967-07-17',
#   '1968-01-16',
#   '1968-02-15',
#   '1968-07-18',
#   '1969-01-14',
#   '1969-02-14',
#   '1969-07-17',
#   '1970-01-16',
#   '1970-02-13',
#   '1970-07-17',
#   '1971-01-18',
#   '1971-02-12',
#   '1971-07-16',
#   '1972-01-21',
#   '1972-02-18',
#   '1972-07-21',
#   '1973-01-19',
#   '1973-02-20',
#   '1973-07-19',
#   '1974-01-17',
#   '1974-02-20',
#   '1974-07-18',
#   '1975-01-16',
# ...

# %%
url = f"https://api.stlouisfed.org/fred/series/observations?series_id=GNPCA&api_key={key}&file_type=json&vintage_dates=1966-02-15"

# %%
resp=requests.get(url)
resp.json()
# Out:
# {'realtime_start': '1966-02-15',
#  'realtime_end': '1966-02-15',
#  'observation_start': '1600-01-01',
#  'observation_end': '9999-12-31',
#  'units': 'lin',
#  'output_type': 1,
#  'file_type': 'json',
#  'order_by': 'observation_date',
#  'sort_order': 'asc',
#  'count': 37,
#  'offset': 0,
#  'limit': 100000,
#  'observations': [{'realtime_start': '1966-02-15',
#    'realtime_end': '1966-02-15',
#    'date': '1929-01-01',
#    'value': '203.6'},
#   {'realtime_start': '1966-02-15',
#    'realtime_end': '1966-02-15',
#    'date': '1930-01-01',
#    'value': '183.3'},
#   {'realtime_start': '1966-02-15',
#    'realtime_end': '1966-02-15',
#    'date': '1931-01-01',
#    'value': '169.2'},
#   {'realtime_start': '1966-02-15',
#    'realtime_end': '1966-02-15',
#    'date': '1932-01-01',
#    'value': '144.1'},
#   {'realtime_start': '1966-02-15',
#    'realtime_end': '1966-02-15',
#    'date': '1933-01-01',
#    'value': '141.5'},
#   {'realtime_start': '1966-02-15',
# ...

# %%
main_url = "https://api.stlouisfed.org/fred/series/search"

# %%
params = {
    'api_key': key,
    'file_type': 'json',
    'search_text': "Real Gross Domestic Product"
}

# %%
resp = requests.get(main_url, params=params)

# %%
{i['id']:i['title'] for i in resp.json()['seriess']}
# Out:
# {'GDPC1': 'Real Gross Domestic Product',
#  'A191RL1Q225SBEA': 'Real Gross Domestic Product',
#  'GDPCA': 'Real Gross Domestic Product',
#  'A191RO1Q156NBEA': 'Real Gross Domestic Product',
#  'A191RL1A225NBEA': 'Real Gross Domestic Product',
#  'ND000334Q': 'Real Gross Domestic Product',
#  'OB000334Q': 'Real Gross Domestic Product',
#  'NB000334Q': 'Real Gross Domestic Product',
#  'A939RX0Q048SBEA': 'Real gross domestic product per capita',
#  'PCECC96': 'Real Personal Consumption Expenditures',
#  'DPCERL1Q225SBEA': 'Real Personal Consumption Expenditures',
#  'PCECCA': 'Real Personal Consumption Expenditures',
#  'GDPPOT': 'Real Potential Gross Domestic Product',
#  'ND000349Q': 'Real Personal Consumption Expenditures',
#  'DPCERO1Q156NBEA': 'Real Personal Consumption Expenditures',
#  'DPCERL1A225NBEA': 'Real Personal Consumption Expenditures',
#  'NB000349Q': 'Real Personal Consumption Expenditures',
#  'OB000349Q': 'Real Personal Consumption Expenditures',
# ...
